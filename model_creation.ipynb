# %% [markdown]
# # EYE DETECTION

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout,Flatten, Conv2D 
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.12.0

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# **Preparing data for training**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_size = 48
batch_size = 64

datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
                                                    target_size=(img_size, img_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode="categorical",
                                                    shuffle=True)

datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("test/",
                                                              target_size=(img_size, img_size),
                                                              color_mode="grayscale",
                                                              batch_size=batch_size,
                                                              class_mode="categorical",
                                                              shuffle=True)
# Out:
# Found 81675 images belonging to 2 classes.
# Found 3223 images belonging to 2 classes.

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
 def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32,(3,3))
    conv_2 = Convolution(inputs,64,(5,5))
    conv_3 = Convolution(inputs,128,(3,3))
    
    flatten = Flatten()(conv_3)
    
    dense_1 = Dense_f(flatten,256)
    
    output = Dense(2,activation = "softmax")(dense_1)
    model = Model(inputs = [inputs], outputs = [output])
    
    model.compile(loss = ['categorical_crossentropy'], optimizer = 'adam', metrics = ['accuracy'])
    
    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Batc  (None, 48, 48, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 18,877,954
# Trainable params: 18,877,186
# Non-trainable params: 768
# _________________________________________________________________

# %% [markdown]
# **Initializing Model**

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

model = model_fer((48,48,1))
epochs = 15
steps_per_epoch = train_generator.n //train_generator.batch_size
validation_steps = validation_generator.n //validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_accuracy', save_weights_only=True, mode='max', verbose=-1)

callbacks = [checkpoint]

# %% [markdown]
#  # TRAINING THE MODEL

# %%
from tensorflow.keras.models import Model

history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/15
# 1276/1276 [==============================] - 1243s 971ms/step - loss: 0.1661 - accuracy: 0.9372 - val_loss: 0.6944 - val_accuracy: 0.7272
# Epoch 2/15
# 1276/1276 [==============================] - 1057s 829ms/step - loss: 0.1003 - accuracy: 0.9633 - val_loss: 0.2210 - val_accuracy: 0.9116
# Epoch 3/15
# 1276/1276 [==============================] - 1000s 783ms/step - loss: 0.0819 - accuracy: 0.9705 - val_loss: 0.7673 - val_accuracy: 0.6756
# Epoch 4/15
# 1276/1276 [==============================] - 1091s 855ms/step - loss: 0.0722 - accuracy: 0.9739 - val_loss: 0.3490 - val_accuracy: 0.8503
# Epoch 5/15
# 1276/1276 [==============================] - 1045s 819ms/step - loss: 0.0618 - accuracy: 0.9777 - val_loss: 0.7599 - val_accuracy: 0.7212
# Epoch 6/15
# 1276/1276 [==============================] - 1124s 881ms/step - loss: 0.0564 - accuracy: 0.9802 - val_loss: 0.6513 - val_accuracy: 0.7653
# Epoch 7/15
# 1276/1276 [==============================] - 1196s 937ms/step - loss: 0.0532 - accuracy: 0.9812 - val_loss: 1.2558 - val_accuracy: 0.6528
# Epoch 8/15
# 1276/1276 [==============================] - 1355s 1s/step - loss: 0.0479 - accuracy: 0.9830 - val_loss: 0.3800 - val_accuracy: 0.8684
# Epoch 9/15
# 1276/1276 [==============================] - 1181s 925ms/step - loss: 0.0428 - accuracy: 0.9849 - val_loss: 0.5457 - val_accuracy: 0.8397
# Epoch 10/15
# 1276/1276 [==============================] - 1264s 990ms/step - loss: 0.0393 - accuracy: 0.9865 - val_loss: 0.9212 - val_accuracy: 0.7697
# Epoch 11/15
# 1276/1276 [==============================] - 1236s 969ms/step - loss: 0.0383 - accuracy: 0.9863 - val_loss: 2.1879 - val_accuracy: 0.6112
# Epoch 12/15
# 1276/1276 [==============================] - 1082s 847ms/step - loss: 0.0351 - accuracy: 0.9875 - val_loss: 0.3563 - val_accuracy: 0.8822
# Epoch 13/15
# 1276/1276 [==============================] - 1162s 911ms/step - loss: 0.0323 - accuracy: 0.9888 - val_loss: 0.6563 - val_accuracy: 0.7750
# Epoch 14/15
# 1276/1276 [==============================] - 1139s 892ms/step - loss: 0.0297 - accuracy: 0.9897 - val_loss: 1.6924 - val_accuracy: 0.6509
# Epoch 15/15
# 1276/1276 [==============================] - 1150s 901ms/step - loss: 0.0301 - accuracy: 0.9893 - val_loss: 0.6617 - val_accuracy: 0.7881

# %% [markdown]
# **Model Evaluation**

# %%
model.evaluate(validation_generator)
# Out:
# 51/51 [==============================] - 6s 106ms/step - loss: 0.6639 - accuracy: 0.7881
# [0.6639044284820557, 0.7880856394767761]

# %% [markdown]
# **Plotting Loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.0, bottom=0.0, right=0.95, left=0.0, hspace=0.25, wspace=0.35)
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.0, bottom=0.0, right=0.95, left=0.0, hspace=0.25, wspace=0.35)
plt.show()

# %% [markdown]
# **Saving Model Architechture**

# %%
model_json = model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
